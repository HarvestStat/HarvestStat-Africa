# %% [markdown]
# # HarvestStat Data Analysis - Madagascar

# %% [markdown]
# ## Issue 1: Year-off issue

# %%
import json, requests
import pandas as pd
host = 'https://fdw.fews.net'
auth = tuple(json.loads(open('token.json', "r").read()))
parameters = {
    'format': 'json',
    'country': 'Madagascar',
    'product': 'R011',
    'survey_type': 'crop:best'
}
endpoint = '/api/cropproductionindicatorvalue/'
response = requests.get(host + endpoint, auth=auth, params=parameters, proxies={})
response.raise_for_status()
df = pd.DataFrame.from_records(response.json())
df[
    (df['product'] == 'Maize (Corn)') &
    (df['indicator'] == 'Quantity Produced')
].pivot_table(index='period_date', columns='fnid', values='value').sum(axis=1).tail(10)
# Out:
# period_date
# 2009-09-30    462520.000000
# 2010-09-30    446729.000000
# 2012-09-30    426657.000000
# 2013-09-30    379246.096558
# 2014-09-30    364128.272258
# 2015-09-30    329366.556790
# 2016-09-30    316331.438744
# 2017-09-30    281487.468508
# 2018-09-30    215000.547016
# 2019-09-30    219220.476429
# dtype: float64

# %% [markdown]
# ## Issue 2: Missing records

# %%
import json, requests
import pandas as pd
host = 'https://fdw.fews.net'
auth = tuple(json.loads(open('token.json', "r").read()))
parameters = {
    'format': 'json',
    'country': 'Madagascar',
    'product': 'R011',
    'survey_type': 'crop:best'
}
endpoint = '/api/cropproductionindicatorvalue/'
response = requests.get(host + endpoint, auth=auth, params=parameters, proxies={})
response.raise_for_status()
df = pd.DataFrame.from_records(response.json())
df[
    (df['product'] == 'Rice (Paddy)')
].pivot_table(index='period_date', columns='indicator', values='value', aggfunc='count')
# Out:
# indicator    Area Harvested  Area Planted  Quantity Produced  Yield
# period_date
# 1964-09-30                0             6                  6      6
# 1965-09-30                0             6                  6      6
# 1966-09-30                0             6                  6      6
# 1967-09-30                0             6                  6      6
# 1968-09-30                0             6                  6      6
# 1969-09-30                0             6                  6      6
# 1970-09-30                0             6                  6      6
# 1972-09-30                0             6                  6      6
# 1973-09-30                0             6                  6      6
# 1974-09-30                0             6                  6      6
# 1976-09-30                0             6                  6      6
# 1977-09-30                0             6                  6      6
# 1978-09-30                0             6                  6      6
# 1980-09-30                0             6                  6      6
# 1981-09-30                0             6                  6      6
# 1982-09-30                0             6                  6      6
# 1983-09-30                0             6                  6      6
# 1984-09-30                0             6                  6      6
# 1985-09-30                0             6                  6      6
# 1986-09-30                0             6                  6      6
# 1990-09-30                0           100                100    100
# 1991-09-30                0           100                100    100
# 1992-09-30                0           101                101    101
# 1993-09-30                0            99                 99     99
# 1994-09-30                0            99                 99     99
# 1995-09-30                0            99                 99     99
# 1996-09-30                0            99                 99     99
# 1997-09-30                0            99                 99     99
# 1998-09-30                0            99                 99     99
# 1999-09-30                0            99                 99     99
# 2000-09-30                0            99                 99     99
# 2001-09-30                0           102                102    102
# 2002-09-30                0           102                102    102
# 2003-09-30                0           102                101    101
# 2004-09-30                0           102                101    101
# 2005-09-30                0           103                103    103
# 2006-09-30                0           103                103    103
# 2007-09-30                0           103                103    103
# 2008-09-30                0           103                103    103
# 2009-09-30                0           103                103    103
# 2010-09-30                0           103                103    103
# 2011-09-30                0           102                102    102
# 2012-09-30                0             0                 22      0
# 2013-09-30                0             0                 22      0
# 2014-09-30                0             0                 22      0
# 2015-09-30                0             0                 22      0
# 2016-09-30                0             0                 22      0
# 2017-09-30                0             0                 22      0
# 2018-09-30                0             0                 22      0
# 2019-09-30                0             0                 22      0

# %% [markdown]
# ## Validation with FAOSTAT and CHIRPS Precipitation

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Load Crop Data ------------------------------------- #
# country_name, season_name, product_name_fdw, product_name_fao,  = 'Madagascar', 'Annual', 'Maize', 'Maize (corn)'
country_name, season_name, product_name_fdw, product_name_fao,  = 'Madagascar', 'Annual', 'Rice', 'Rice'
shape_code, prcp_start_month, prcp_season_name, prcp_year_offset = 'MG2009A0', 1, 'JFM PRCP (mm)', +1
# HarvestStat
df = pd.read_csv('../public/hvstat_africa_data_v1.1.csv', index_col=0)
df = df[
    (df['country'] == country_name) &
    (df['season_name'] == season_name) &
    (df['product'].isin([product_name_fdw]))
].copy()
df['year'] = df['harvest_year']
data_hs = df.pivot_table(index='year',columns='product',values='production',aggfunc='sum').squeeze()
# FAO-STAT
df = pd.read_csv('../data/crop/adm_fao_stat.csv', index_col=0)
data_fao = df[
    (df['Area'] == country_name) &
    (df['Item'] == product_name_fao) &
    (df['Element'] == 'Production')
].set_index('Year')['Value']
# Merge
prod = pd.concat([data_fao,data_hs], axis=1, keys=['FAO','HS']).sort_index()
prod = prod.reindex(np.array(range(1982,2024)))
fig, ax1 = plt.subplots(figsize=(7,3))
fig.set_facecolor('white')
prod.plot(ax=ax1, grid=True, markerfacecolor='None',color=['#F55A05','#2C7BDD'])
marker = ['.','s']
for i, line in enumerate(ax1.get_lines()):
    line.set_marker(marker[i])
title = f'{country_name} {season_name}-{product_name_fdw}-Production'# and {prcp_label}'
ax1.set_title(title)
fig.tight_layout()
plt.show()

# ---------------------------------------------------- #
df = pd.read_csv('../public/hvstat_africa_data_v1.1.csv', index_col=0)
df = df[
    (df['country'] == country_name) &
    (df['season_name'] == season_name) &
    (df['product'].isin([product_name_fdw]))
].copy()
df['year'] = df['harvest_year']
data_hs = df.pivot_table(index='year',columns='product',values='area',aggfunc='sum').squeeze()
# FAO-STAT
df = pd.read_csv('../data/crop/adm_fao_stat.csv', index_col=0)
data_fao = df[
    (df['Area'] == country_name) &
    (df['Item'] == product_name_fao) &
    (df['Element'] == 'Area harvested')
].set_index('Year')['Value']
# Merge
area = pd.concat([data_fao,data_hs], axis=1, keys=['FAO','HS']).sort_index()
area = area.reindex(np.array(range(1982,2024)))
fig, ax1 = plt.subplots(figsize=(7,3))
fig.set_facecolor('white')
area.plot(ax=ax1, grid=True, markerfacecolor='None',color=['#F55A05','#2C7BDD'])
marker = ['.','s']
for i, line in enumerate(ax1.get_lines()):
    line.set_marker(marker[i])
title = f'{country_name} {season_name}-{product_name_fdw}-Area'# and {prcp_label}'
ax1.set_title(title)
fig.tight_layout()
plt.show()
# ---------------------------------------------------- #
yld = prod/area

fig, ax1 = plt.subplots(figsize=(7,3))
fig.set_facecolor('white')
yld.plot(ax=ax1, grid=True, markerfacecolor='None',color=['#F55A05','#2C7BDD'])
marker = ['.','s']
for i, line in enumerate(ax1.get_lines()):
    line.set_marker(marker[i])
title = f'{country_name} {season_name}-{product_name_fdw}-Yield'# and {prcp_label}'
ax1.set_title(title)
fig.tight_layout()
plt.show()
# ---------------------------------------------------- #

# %%
# Out:
# year
# 1990    153447.000000
# 1991    143380.000000
# 1992    128614.000000
# 1993    163240.000000
# 1994    153345.000000
# 1995    175115.000000
# 1996    177575.000000
# 1997    179585.000000
# 1998    156255.000000
# 1999    172180.000000
# 2000    167910.000000
# 2001    177550.000000
# 2002    170879.000000
# 2003    269452.000000
# 2004    259584.000000
# 2005    387303.000000
# 2006    391068.000000
# 2007    449668.000000
# 2008    537183.000000
# 2009    462520.000000
# 2010    446729.000000
# 2012    426657.000000
# 2013    379246.096558
# 2014    364128.272258
# 2015    329366.556790
# 2016    316331.438744
# 2017    281487.468508
# 2018    215000.547016
# 2019    219220.476429
# Name: Maize, dtype: float64

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Load Crop Data ------------------------------------- #
# country_name, season_name, product_name_fdw, product_name_fao,  = 'Madagascar', 'Annual', 'Maize', 'Maize (corn)'
country_name, season_name, product_name_fdw, product_name_fao,  = 'Madagascar', 'Annual', 'Maize', 'Maize (corn)'
shape_code, prcp_start_month, prcp_season_name, prcp_year_offset = 'MG2009A0', 1, 'JFM PRCP (mm)', +1
# HarvestStat
df = pd.read_csv('../public/hvstat_africa_data_v1.1.csv', index_col=0)
df = df[
    (df['country'] == country_name) &
    (df['season_name'] == season_name) &
    (df['product'].isin([product_name_fdw]))
].copy()
df['year'] = df['harvest_year']
data_hs = df.pivot_table(index='year',columns='product',values='production',aggfunc='sum').squeeze()
# FAO-STAT
df = pd.read_csv('../data/crop/adm_fao_stat.csv', index_col=0)
data_fao = df[
    (df['Area'] == country_name) &
    (df['Item'] == product_name_fao) &
    (df['Element'] == 'Production')
].set_index('Year')['Value']
# Merge
prod = pd.concat([data_fao,data_hs], axis=1, keys=['FAO','HS']).sort_index()
prod = prod.reindex(np.array(range(1982,2024)))
fig, ax1 = plt.subplots(figsize=(7,3))
fig.set_facecolor('white')
prod.plot(ax=ax1, grid=True, markerfacecolor='None',color=['#F55A05','#2C7BDD'])
marker = ['.','s']
for i, line in enumerate(ax1.get_lines()):
    line.set_marker(marker[i])
title = f'{country_name} {season_name}-{product_name_fdw}-Production'# and {prcp_label}'
ax1.set_title(title)
fig.tight_layout()
plt.show()

# ---------------------------------------------------- #
df = pd.read_csv('../public/hvstat_africa_data_v1.1.csv', index_col=0)
df = df[
    (df['country'] == country_name) &
    (df['season_name'] == season_name) &
    (df['product'].isin([product_name_fdw]))
].copy()
df['year'] = df['harvest_year']
data_hs = df.pivot_table(index='year',columns='product',values='area',aggfunc='sum').squeeze()
# FAO-STAT
df = pd.read_csv('../data/crop/adm_fao_stat.csv', index_col=0)
data_fao = df[
    (df['Area'] == country_name) &
    (df['Item'] == product_name_fao) &
    (df['Element'] == 'Area harvested')
].set_index('Year')['Value']
# Merge
area = pd.concat([data_fao,data_hs], axis=1, keys=['FAO','HS']).sort_index()
area = area.reindex(np.array(range(1982,2024)))
fig, ax1 = plt.subplots(figsize=(7,3))
fig.set_facecolor('white')
area.plot(ax=ax1, grid=True, markerfacecolor='None',color=['#F55A05','#2C7BDD'])
marker = ['.','s']
for i, line in enumerate(ax1.get_lines()):
    line.set_marker(marker[i])
title = f'{country_name} {season_name}-{product_name_fdw}-Area'# and {prcp_label}'
ax1.set_title(title)
fig.tight_layout()
plt.show()
# ---------------------------------------------------- #
yld = prod/area
yld = yld.loc[yld.index!=2003] #remove 2003, which has too smal harvested area
fig, ax1 = plt.subplots(figsize=(7,3))
fig.set_facecolor('white')
yld.plot(ax=ax1, grid=True, markerfacecolor='None',color=['#F55A05','#2C7BDD'])
marker = ['.','s']
for i, line in enumerate(ax1.get_lines()):
    line.set_marker(marker[i])
title = f'{country_name} {season_name}-{product_name_fdw}-Yield'# and {prcp_label}'
ax1.set_title(title)
fig.tight_layout()
plt.show()
# ---------------------------------------------------- #

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Load Crop Data ------------------------------------- #
# country_name, season_name, product_name_fdw, product_name_fao,  = 'Madagascar', 'Annual', 'Maize', 'Maize (corn)'
country_name, season_name, product_name_fdw, product_name_fao,  = 'Madagascar', 'Annual', 'Cassava', 'Cassava, fresh'
shape_code, prcp_start_month, prcp_season_name, prcp_year_offset = 'MG2009A0', 1, 'JFM PRCP (mm)', +1
# HarvestStat
df = pd.read_csv('../public/hvstat_africa_data_v1.1.csv', index_col=0)
df = df[
    (df['country'] == country_name) &
    (df['season_name'] == season_name) &
    (df['product'].isin([product_name_fdw]))
].copy()
df['year'] = df['harvest_year']
data_hs = df.pivot_table(index='year',columns='product',values='production',aggfunc='sum').squeeze()
# FAO-STAT
df = pd.read_csv('../data/crop/FAO_cassava.csv', index_col=0)
data_fao = df[
    (df['Area'] == country_name) &
    (df['Item'] == product_name_fao) &
    (df['Element'] == 'Production')
].set_index('Year')['Value']
# Merge
prod = pd.concat([data_fao,data_hs], axis=1, keys=['FAO','HS']).sort_index()
prod = prod.reindex(np.array(range(1982,2024)))
fig, ax1 = plt.subplots(figsize=(7,3))
fig.set_facecolor('white')
prod.plot(ax=ax1, grid=True, markerfacecolor='None',color=['#F55A05','#2C7BDD'])
marker = ['.','s']
for i, line in enumerate(ax1.get_lines()):
    line.set_marker(marker[i])
title = f'{country_name} {season_name}-{product_name_fdw}-Production'# and {prcp_label}'
ax1.set_title(title)
fig.tight_layout()
plt.show()

# ---------------------------------------------------- #
df = pd.read_csv('../public/hvstat_africa_data_v1.1.csv', index_col=0)
df = df[
    (df['country'] == country_name) &
    (df['season_name'] == season_name) &
    (df['product'].isin([product_name_fdw])) 
].copy()
df['year'] = df['harvest_year']
data_hs = df.pivot_table(index='year',columns='product',values='area',aggfunc='sum').squeeze()
# FAO-STAT
df = pd.read_csv('../data/crop/FAO_cassava.csv', index_col=0)
data_fao = df[
    (df['Area'] == country_name) &
    (df['Item'] == product_name_fao) &
    (df['Element'] == 'Area harvested')
].set_index('Year')['Value']
# Merge
area = pd.concat([data_fao,data_hs], axis=1, keys=['FAO','HS']).sort_index()
area = area.reindex(np.array(range(1982,2024)))
fig, ax1 = plt.subplots(figsize=(7,3))
fig.set_facecolor('white')
area.plot(ax=ax1, grid=True, markerfacecolor='None',color=['#F55A05','#2C7BDD'])
marker = ['.','s']
for i, line in enumerate(ax1.get_lines()):
    line.set_marker(marker[i])
title = f'{country_name} {season_name}-{product_name_fdw}-Area'# and {prcp_label}'
ax1.set_title(title)
fig.tight_layout()
plt.show()
# ---------------------------------------------------- #
yld = prod/area

fig, ax1 = plt.subplots(figsize=(7,3))
fig.set_facecolor('white')
yld.plot(ax=ax1, grid=True, markerfacecolor='None',color=['#F55A05','#2C7BDD'])
marker = ['.','s']
for i, line in enumerate(ax1.get_lines()):
    line.set_marker(marker[i])
title = f'{country_name} {season_name}-{product_name_fdw}-Yield'# and {prcp_label}'
ax1.set_title(title)
fig.tight_layout()
plt.show()
# ---------------------------------------------------- #
