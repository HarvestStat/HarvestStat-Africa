# %% [markdown]
# # HarvestStat Data Profiling - Mozambique

# %%
import glob
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
import numpy as np
import pandas as pd
import geopandas as gpd
from tools import retreive_fdw_data, save_npz, PrintAdminUnits, PlotAdminShapes
from tools import FDW_PD_Sweeper, FDW_PD_AvalTable, FDW_PD_Compiling, FDW_PD_ValidateFnidName
from tools import FDW_PD_CreateAdminLink, FDW_PD_RatioAdminLink, FDW_PD_ConnectAdminLink
from tools import product_name_mapping, FDW_PD_CaliSeasonYear, FDW_PD_MergeCropProductionSystem
from tools_graphic import PlotBarProduction, PlotLinePAY
warnings.simplefilter(action='ignore', category=pd.errors.PerformanceWarning)
pd.options.mode.chained_assignment = None

# %%
# Set loading parameters ------------------------ #
country_name = 'Mozambique'
country_iso2 = 'MZ'
use_api_data = True
requires_authentication = False
# ----------------------------------------------- #

# Load FEWS NET administrative boundaries ------- #
epsg = 'EPSG:32736' # Mozambique
fn_shapes = sorted(glob.glob(f"../data/shapefile/fewsnet/{country_iso2}_Admin?_????.shp"))
shape_all = []
for fn in fn_shapes:
    name = fn[-18:-4]
    exec('%s = gpd.read_file("%s").to_crs("%s")' % (name, fn, epsg))
    exec('%s["area"] = %s["geometry"].area/10**6' % (name, name))
    exec('shape_all.append(%s)' % (name))
shape_all = pd.concat(shape_all, axis=0).reset_index(drop=True)
# PrintAdminUnits(shape_all)
# ----------------------------------------------- #

# Load FDW data -------------------------------- #
df = retreive_fdw_data(country_name, country_iso2, use_api_data, requires_authentication)
# ----------------------------------------------- #
# Out:
# Data is retrieved from the FDW API.
# ../data/crop_raw_data/adm_crop_data_raw_MZ.csv is saved.

# %%
# Manual Pre-processing before Sweeping --------- #
# Default setting 
# a) None-type crop production system
df.loc[df['crop_production_system'].isna(), 'crop_production_system'] = 'none'
df.loc[df['crop_production_system'] == '', 'crop_production_system'] = 'none'
# b) None-type population group
df.loc[df['population_group'].isna(), 'population_group'] = 'none'
df.loc[df['population_group'] == '', 'population_group'] = 'none'
# Remove the 2005 Sweet Potatoes data (unreliable data, Donghoon)
rdx = df[(df['season_year']=='Main harvest 2005') & (df['product']=='Sweet Potatoes')]
df = df.drop(rdx.index)
# Change the season name
df['season_name'] = df['season_name'].replace({'Main harvest': 'Main'})
#Remove the "Alt" documents
df = df.loc[df.source_document.str[:4]!='Alt_']
# ----------------------------------------------- #




# FDW Production Data Inspection ---------------- #
df, df_raw = FDW_PD_Sweeper(df)
table_dict = FDW_PD_AvalTable(df, shape_all)
# ----------------------------------------------- #

# FEWS NET Shapefile comparison ----------------- #
shape_used = pd.concat([MZ_Admin1_1990 ,MZ_Admin1_2013, MZ_Admin1_2016, MZ_Admin1_2021], axis=0)
PlotAdminShapes(shape_used, label=True)
# ----------------------------------------------- #
# Out:
# - Remove missing records ---------------------- #
# Orignial data points: 18,820
# Removed 9,482 "Missing Value" points
# 0/4,705 "Area Harvested" points are retained.
# 3,439/4,705 "Area Planted" points are retained.
# 3,291/4,705 "Quantity Produced" points are retained.
# 2,608/4,705 "Yield" points are retained.
# Current data points: 9,338
#
# - Minor changes are applied ------------------- #
#
# - Basic information --------------------------- #
# Data period: 1999 - 2022
# 57 grain types are found: Bambara groundnut, Banana (unspecified), Beans (Lima), Beans (Rosecoco), Beans (mixed), Beet, Cabbage (Unspecified), Capsicum frutescens,unspecified, Carrots, Cashew (unshelled), Cassava, Chili pepper (Unspecified), Cotton (Unspecified), Cowpea (unspecified), Cucumber, Eggplant, Garlic (fresh), Ginger, Green bean (fresh), Groundnuts (In Shell), Groundnuts (In Shell, Large), Groundnuts (In Shell, Small), Jute, Kale, Lettuce (Unspecified), Macadamia (unspecified), Maize Grain (White), Millet, Mung bean (unspecified), Okras (Fresh), Onions, Other root/tuber vegetable (unspecified), Paprika (unspecified), Pea (unspecified), Pepper (Piper spp.), Pigeon pea (Unspecified), Potato (Irish), Potato (unspecified), Rice (Paddy), Sesame Seed, Sisal, Sorghum, Soybean (unspecified), Spanish peanut (in shell), Squash (Pumpkin, Zucchini), Sugarcane (for sugar), Sunflower Seed, Sweet Potatoes, Sweet Potatoes (Non-Orange), Sweet Potatoes (Orange), Tea leaves (Mixed), Tobacco (unspecified), Tomato, Virginia peanut (in shell), Watermelon, Wheat Grain, Yams
# 5 seasons are found: Cotton season (08-01), Rice season (05-01), Main (04-01), Annual (04-01), Winter harvest (09-01)
# 1 crop production system are found: All (PS)
# Data sources include:
# [1] INE, Mozambique --- Censo Agro-Pecuário, Mozambique
# [2] INE, Mozambique --- Indicadores Básicos de Agricultura e Alimentação, Mozambique
# [3] Ministério da Agricultura e Segurança Alimentar (MASA), Mozambique --- Anuário de Estatísticas Agrárias, Mozambique
# [4] Ministério da Agricultura e Segurança Alimentar (MASA), Mozambique --- FEWS Agro_Maps, Mozambique
# [5] Ministério da Agricultura e Segurança Alimentar (MASA), Mozambique --- Inquérito Agrário Integrado, Mozambique
# [6] Ministério da Agricultura e Segurança Alimentar (MASA), Mozambique --- MASA/FAO study, Mozambique
# Administrative-1 fnids: 42
# Administrative-2 fnids: 0
# 0 reporting units are found:
#
# - Total production over time ------------------ #
# season_name                              Annual Cotton season   Main  \
#
# Bambara groundnut                          0.0%          0.0%   0.1%
# Banana (unspecified)                       0.0%          0.0%   0.0%
# Beans (Lima)                               0.0%          0.0%   0.2%
# Beans (Rosecoco)                           0.0%          0.0%   0.2%
# Beans (mixed)                              0.0%          0.0%   1.1%
# Cashew (unshelled)                        11.7%          0.0%   0.0%
# Cassava                                   54.4%          0.0%   0.0%
# Chili pepper (Unspecified)                 0.0%          0.0%   0.0%
# Cotton (Unspecified)                       0.0%          0.6%   0.0%
# Cowpea (unspecified)                       0.0%          0.0%   0.6%
# Ginger                                     0.0%          0.0%   0.0%
# Green bean (fresh)                         0.0%          0.0%   0.2%
# Groundnuts (In Shell)                      0.0%          0.0%   0.7%
# Groundnuts (In Shell, Large)               0.0%          0.0%   0.1%
# Groundnuts (In Shell, Small)               0.0%          0.0%   0.1%
# Jute                                       0.0%          0.0%   0.0%
# Macadamia (unspecified)                    0.0%          0.0%   0.0%
# Maize Grain (White)                        0.0%          0.0%  10.1%
# Millet                                     0.0%          0.0%   0.2%
# Mung bean (unspecified)                    0.0%          0.0%   0.0%
# Other root/tuber vegetable (unspecified)   9.7%          0.0%   0.0%
# Paprika (unspecified)                      0.0%          0.0%   0.0%
# Pepper (Piper spp.)                        0.0%          0.0%   0.0%
# Pigeon pea (Unspecified)                   0.0%          0.0%   0.6%
# Rice (Paddy)                               0.0%          0.0%   0.0%
# Sesame Seed                                0.0%          0.0%   0.3%
# Sorghum                                    0.0%          0.0%   2.2%
# Soybean (unspecified)                      0.0%          0.0%   0.0%
# Spanish peanut (in shell)                  0.0%          0.0%   0.4%
# Sugarcane (for sugar)                      0.9%          0.0%   0.0%
# Sunflower Seed                             0.0%          0.0%   0.0%
# Sweet Potatoes                             0.0%          0.0%   1.8%
# Sweet Potatoes (Non-Orange)                0.0%          0.0%   1.5%
# Sweet Potatoes (Orange)                    0.0%          0.0%   0.6%
# Tea leaves (Mixed)                         0.0%          0.0%   0.0%
# Tobacco (unspecified)                      0.0%          0.0%   0.4%
# Virginia peanut (in shell)                 0.0%          0.0%   0.2%
# Wheat Grain                                0.0%          0.0%   0.0%
#
# season_name                              Rice season
#
# Bambara groundnut                               0.0%
# Banana (unspecified)                            0.1%
# Beans (Lima)                                    0.0%
# Beans (Rosecoco)                                0.0%
# Beans (mixed)                                   0.0%
# Cashew (unshelled)                              0.0%
# Cassava                                         0.0%
# Chili pepper (Unspecified)                      0.0%
# Cotton (Unspecified)                            0.0%
# Cowpea (unspecified)                            0.0%
# Ginger                                          0.0%
# Green bean (fresh)                              0.0%
# Groundnuts (In Shell)                           0.0%
# Groundnuts (In Shell, Large)                    0.0%
# Groundnuts (In Shell, Small)                    0.0%
# Jute                                            0.0%
# Macadamia (unspecified)                         0.0%
# Maize Grain (White)                             0.0%
# Millet                                          0.0%
# Mung bean (unspecified)                         0.0%
# Other root/tuber vegetable (unspecified)        0.0%
# Paprika (unspecified)                           0.0%
# Pepper (Piper spp.)                             0.0%
# Pigeon pea (Unspecified)                        0.0%
# Rice (Paddy)                                    1.0%
# Sesame Seed                                     0.0%
# Sorghum                                         0.0%
# Soybean (unspecified)                           0.0%
# Spanish peanut (in shell)                       0.0%
# Sugarcane (for sugar)                           0.0%
# Sunflower Seed                                  0.0%
# Sweet Potatoes                                  0.0%
# Sweet Potatoes (Non-Orange)                     0.0%
# Sweet Potatoes (Orange)                         0.0%
# Tea leaves (Mixed)                              0.0%
# Tobacco (unspecified)                           0.0%
# Virginia peanut (in shell)                      0.0%
# Wheat Grain                                     0.0%
#
# - Crop calendar ------------------------------- #
#                                      product     season_name planting_month  \
# 0                          Bambara groundnut            Main          04-01
# 1                       Banana (unspecified)     Rice season          05-01
# 2                               Beans (Lima)            Main          04-01
# 3                           Beans (Rosecoco)            Main          04-01
# 4                              Beans (mixed)            Main          04-01
# 5                                       Beet            Main          04-01
# 6                      Cabbage (Unspecified)            Main          04-01
# 7            Capsicum frutescens,unspecified            Main          04-01
# 8                                    Carrots            Main          04-01
# 9                         Cashew (unshelled)          Annual          04-01
# 10                                   Cassava          Annual          04-01
# 11                Chili pepper (Unspecified)            Main          04-01
# 12                      Cotton (Unspecified)   Cotton season          08-01
# 13                      Cowpea (unspecified)            Main          04-01
# 14                                  Cucumber            Main          04-01
# 15                                  Eggplant            Main          04-01
# 16                            Garlic (fresh)            Main          04-01
# 17                                    Ginger            Main          04-01
# 18                        Green bean (fresh)            Main          04-01
# 19                     Groundnuts (In Shell)            Main          04-01
# 20              Groundnuts (In Shell, Large)            Main          04-01
# 21              Groundnuts (In Shell, Small)            Main          04-01
# 22                                      Jute          Annual          04-01
# 23                                      Kale            Main          04-01
# 24                     Lettuce (Unspecified)            Main          04-01
# 25                   Macadamia (unspecified)          Annual          04-01
# 26                       Maize Grain (White)            Main          04-01
# 27                                    Millet            Main          04-01
# 28                   Mung bean (unspecified)            Main          04-01
# 29                             Okras (Fresh)            Main          04-01
# 30                                    Onions            Main          04-01
# 31  Other root/tuber vegetable (unspecified)          Annual          04-01
# 32                     Paprika (unspecified)            Main          04-01
# 33                         Pea (unspecified)            Main          04-01
# 34                       Pepper (Piper spp.)            Main          04-01
# 35                  Pigeon pea (Unspecified)            Main          04-01
# 36                            Potato (Irish)            Main          04-01
# 37                      Potato (unspecified)            Main          04-01
# 38                              Rice (Paddy)     Rice season          05-01
# 39                               Sesame Seed            Main          04-01
# 40                                     Sisal            Main          04-01
# 41                                   Sorghum            Main          04-01
# 42                     Soybean (unspecified)            Main          04-01
# 43                 Spanish peanut (in shell)            Main          04-01
# 44                Squash (Pumpkin, Zucchini)            Main          04-01
# 45                     Sugarcane (for sugar)          Annual          04-01
# 46                     Sugarcane (for sugar)            Main          04-01
# 47                            Sunflower Seed            Main          04-01
# 48                            Sweet Potatoes            Main          04-01
# 49               Sweet Potatoes (Non-Orange)            Main          04-01
# 50                   Sweet Potatoes (Orange)            Main          04-01
# 51                        Tea leaves (Mixed)            Main          04-01
# 52                        Tea leaves (Mixed)          Annual          04-01
# 53                     Tobacco (unspecified)            Main          04-01
# 54                                    Tomato            Main          04-01
# 55                Virginia peanut (in shell)            Main          04-01
# 56                                Watermelon            Main          04-01
# 57                               Wheat Grain  Winter harvest          09-01
# 58                               Wheat Grain            Main          04-01
# 59                                      Yams            Main          04-01
#
#    harvest_month
# 0          04-01
# 1          05-01
# 2          04-01
# 3          04-01
# 4          04-01
# 5          04-01
# 6          04-01
# 7          04-01
# 8          04-01
# 9          04-01
# 10         04-01
# 11         04-01
# 12         08-01
# 13         04-01
# 14         04-01
# 15         04-01
# 16         04-01
# 17         04-01
# 18         04-01
# 19         04-01
# 20         04-01
# 21         04-01
# 22         04-01
# 23         04-01
# 24         04-01
# 25         04-01
# 26         04-01
# 27         04-01
# 28         04-01
# 29         04-01
# 30         04-01
# 31         04-01
# 32         04-01
# 33         04-01
# 34         04-01
# 35         04-01
# 36         04-01
# 37         04-01
# 38         05-01
# 39         04-01
# 40         04-01
# 41         04-01
# 42         04-01
# 43         04-01
# 44         04-01
# 45         04-01
# 46         04-01
# 47         04-01
# 48         04-01
# 49         04-01
# 50         04-01
# 51         04-01
# 52         04-01
# 53         04-01
# 54         04-01
# 55         04-01
# 56         04-01
# 57         09-01
# 58         04-01
# 59         04-01
#
# - Recorded years per season ------------------- #
# Cotton season: 22 years (1999-2020) (missing: 4 years)
# Rice season: 24 years (1999-2022) (missing: 5 years)
# Main: 24 years (1999-2022) (missing: 0 years)
# Annual: 24 years (1999-2022) (missing: 1 years)
# Winter harvest: 1 years (2015-2015) (missing: 0 years)
#
# - Number of "Quantity Produced" data points --- #
# MZ1990A1: 1,746 data points are found.
# MZ2013A1: 302 data points are found.
# MZ2016A1: 925 data points are found.
# MZ2021A1: 318 data points are found.
#
# - Districts with population group(s) ---------- #
# 0 districts includes 'population_group'.
#
# Table of available data
# ----------------------------------------------- #
# Crop type: Bambara groundnut
# ----------------------------------------------- #
# season_name                Main
# crop_production_system All (PS)
# fnid_short               1990A1 2013A1 2016A1 2021A1
# year
# 2002                      11/11    NaN    NaN    NaN
# 2003                      11/11    NaN    NaN    NaN
# 2004                        NaN    NaN    NaN    NaN
# 2005                      11/11    NaN    NaN    NaN
# 2006                      11/11    NaN    NaN    NaN
# 2007                      10/11    NaN    NaN    NaN
# 2008                      10/11    NaN    NaN    NaN
# 2009                        NaN    NaN    NaN    NaN
# 2010                      11/11    NaN    NaN    NaN
# 2011                        NaN    NaN    NaN    NaN
# 2012                      10/11    NaN    NaN    NaN
# 2013                        NaN    NaN    NaN    NaN
# 2014                        NaN  10/11    NaN    NaN
# 2015                        NaN  10/11    NaN    NaN
# 2016                        NaN    NaN  10/11    NaN
# 2017                        NaN    NaN  10/11    NaN
# 2018                        NaN    NaN  10/11    NaN
# 2019                        NaN    NaN  10/11    NaN
# 2020                        NaN    NaN  10/11    NaN
# 2021                        NaN    NaN    NaN  10/11
# 2022                        NaN    NaN    NaN  10/11
# ----------------------------------------------- #
# Crop type: Banana (unspecified)
# ----------------------------------------------- #
# season_name            Rice season
# crop_production_system    All (PS)
# fnid_short                  2016A1
# year
# 2020                          3/11
# ----------------------------------------------- #
# Crop type: Beans (Lima)
# ----------------------------------------------- #
# season_name                Main
# crop_production_system All (PS)
# fnid_short               1990A1 2013A1
# year
# 2002                      11/11    NaN
# 2003                      11/11    NaN
# 2004                        NaN    NaN
# 2005                      11/11    NaN
# 2006                      10/11    NaN
# 2007                      10/11    NaN
# 2008                      10/11    NaN
# 2009                        NaN    NaN
# 2010                      11/11    NaN
# 2011                        NaN    NaN
# 2012                      10/11    NaN
# 2013                        NaN    NaN
# 2014                        NaN   9/11
# ----------------------------------------------- #
# Crop type: Beans (Rosecoco)
# ----------------------------------------------- #
# season_name                Main
# crop_production_system All (PS)
# fnid_short               1990A1 2013A1 2016A1 2021A1
# year
# 2010                      11/11    NaN    NaN    NaN
# 2011                        NaN    NaN    NaN    NaN
# 2012                      10/11    NaN    NaN    NaN
# 2013                        NaN    NaN    NaN    NaN
# 2014                        NaN   9/11    NaN    NaN
# 2015                        NaN   6/11    NaN    NaN
# 2016                        NaN    NaN  10/11    NaN
# 2017                        NaN    NaN  10/11    NaN
# 2018                        NaN    NaN  10/11    NaN
# 2019                        NaN    NaN  10/11    NaN
# 2020                        NaN    NaN  10/11    NaN
# 2021                        NaN    NaN    NaN  10/11
# 2022                        NaN    NaN    NaN  10/11
# ----------------------------------------------- #
# Crop type: Beans (mixed)
# ----------------------------------------------- #
# season_name                Main
# crop_production_system All (PS)
# fnid_short               1990A1 2013A1 2016A1
# year
# 1999                       7/11    NaN    NaN
# 2000                      10/11    NaN    NaN
# 2001                      10/11    NaN    NaN
# 2002                      10/11    NaN    NaN
# 2003                      10/11    NaN    NaN
# 2004                      10/11    NaN    NaN
# 2005                      10/11    NaN    NaN
# 2006                      10/11    NaN    NaN
# 2007                      10/11    NaN    NaN
# 2008                      10/11    NaN    NaN
# 2009                      10/11    NaN    NaN
# 2010                      10/11    NaN    NaN
# 2011                      10/11    NaN    NaN
# 2012                        NaN    NaN    NaN
# 2013                        NaN    NaN    NaN
# 2014                        NaN    NaN    NaN
# 2015                        NaN  10/11    NaN
# 2016                        NaN    NaN    NaN
# 2017                        NaN    NaN    NaN
# 2018                        NaN    NaN  10/11
# ----------------------------------------------- #
# Crop type: Beet
# ----------------------------------------------- #
# season_name                Main
# crop_production_system All (PS)
# fnid_short               1990A1 2013A1
# year
# 2010                       2/11    NaN
# 2011                        NaN    NaN
# 2012                        NaN    NaN
# 2013                        NaN    NaN
# 2014                        NaN    NaN
# 2015                        NaN   2/11
# ----------------------------------------------- #
# Crop type: Cabbage (Unspecified)
# ----------------------------------------------- #
# season_name                Main
# crop_production_system All (PS)
# fnid_short               1990A1 2013A1
# year
# 2010                      11/11    NaN
# 2011                        NaN    NaN
# 2012                        NaN    NaN
# 2013                        NaN    NaN
# 2014                        NaN    NaN
# 2015                        NaN   9/11
# ----------------------------------------------- #
# Crop type: Capsicum frutescens,unspecified
# ----------------------------------------------- #
# season_name                Main
# crop_production_system All (PS)
# fnid_short               1990A1 2013A1
# year
# 2010                       8/11    NaN
# 2011                        NaN    NaN
# 2012                        NaN    NaN
# 2013                        NaN    NaN
# 2014                        NaN    NaN
# 2015                        NaN   5/11
# ----------------------------------------------- #
# Crop type: Carrots
# ----------------------------------------------- #
# season_name                Main
# crop_production_system All (PS)
# fnid_short               1990A1 2013A1
# year
# 2000                       4/11    NaN
# 2001                        NaN    NaN
# 2002                        NaN    NaN
# 2003                        NaN    NaN
# 2004                        NaN    NaN
# 2005                        NaN    NaN
# 2006                        NaN    NaN
# 2007                        NaN    NaN
# 2008                        NaN    NaN
# 2009                        NaN    NaN
# 2010                      11/11    NaN
# 2011                        NaN    NaN
# 2012                        NaN    NaN
# 2013                        NaN    NaN
# 2014                        NaN    NaN
# 2015                        NaN   6/11
# ----------------------------------------------- #
# Crop type: Cashew (unshelled)
# ----------------------------------------------- #
# season_name              Annual
# crop_production_system All (PS)
# fnid_short               2013A1 2016A1 2021A1
# year
# 2015                       8/11    NaN    NaN
# 2016                        NaN   8/11    NaN
# 2017                        NaN   8/11    NaN
# 2018                        NaN   9/11    NaN
# 2019                        NaN   9/11    NaN
# 2020                        NaN   9/11    NaN
# 2021                        NaN    NaN   9/11
# 2022                        NaN    NaN   9/11
# ----------------------------------------------- #
# Crop type: Cassava
# ----------------------------------------------- #
# season_name              Annual
# crop_production_system All (PS)
# fnid_short               1990A1 2013A1 2016A1 2021A1
# year
# 1999                       5/11    NaN    NaN    NaN
# 2000                      10/11    NaN    NaN    NaN
# 2001                      10/11    NaN    NaN    NaN
# 2002                      11/11    NaN    NaN    NaN
# 2003                      10/11    NaN    NaN    NaN
# 2004                      10/11    NaN    NaN    NaN
# 2005                      11/11    NaN    NaN    NaN
# 2006                      11/11    NaN    NaN    NaN
# 2007                      10/11    NaN    NaN    NaN
# 2008                      10/11    NaN    NaN    NaN
# 2009                      10/11    NaN    NaN    NaN
# 2010                      11/11    NaN    NaN    NaN
# 2011                      10/11    NaN    NaN    NaN
# 2012                      10/11    NaN    NaN    NaN
# 2013                        NaN    NaN    NaN    NaN
# 2014                        NaN  10/11    NaN    NaN
# 2015                        NaN  10/11    NaN    NaN
# 2016                        NaN    NaN  10/11    NaN
# 2017                        NaN    NaN  10/11    NaN
# 2018                        NaN    NaN  10/11    NaN
# 2019                        NaN    NaN  10/11    NaN
# 2020                        NaN    NaN  10/11    NaN
# 2021                        NaN    NaN    NaN  10/11
# 2022                        NaN    NaN    NaN  10/11
# ----------------------------------------------- #
# Crop type: Chili pepper (Unspecified)
# ----------------------------------------------- #
# season_name                Main
# crop_production_system All (PS)
# fnid_short               1990A1 2013A1
# year
# 2010                       2/11    NaN
# 2011                        NaN    NaN
# 2012                        NaN    NaN
# 2013                        NaN    NaN
# 2014                        NaN    NaN
# 2015                        NaN   2/11
# ----------------------------------------------- #
# Crop type: Cotton (Unspecified)
# ----------------------------------------------- #
# season_name            Cotton season
# crop_production_system      All (PS)
# fnid_short                    1990A1 2013A1 2016A1
# year
# 1999                            6/11    NaN    NaN
# 2000                           10/11    NaN    NaN
# 2001                             NaN    NaN    NaN
# 2002                            8/11    NaN    NaN
# 2003                            9/11    NaN    NaN
# 2004                             NaN    NaN    NaN
# 2005                            8/11    NaN    NaN
# 2006                            8/11    NaN    NaN
# 2007                            9/11    NaN    NaN
# 2008                            8/11    NaN    NaN
# 2009                             NaN    NaN    NaN
# 2010                            9/11    NaN    NaN
# 2011                             NaN    NaN    NaN
# 2012                            9/11    NaN    NaN
# 2013                             NaN   9/11    NaN
# 2014                             NaN   9/11    NaN
# 2015                             NaN   5/11    NaN
# 2016                             NaN    NaN   9/11
# 2017                             NaN    NaN   9/11
# 2018                             NaN    NaN   9/11
# 2019                             NaN    NaN   9/11
# 2020                             NaN    NaN   8/11
# ----------------------------------------------- #
# Crop type: Cowpea (unspecified)
# ----------------------------------------------- #
# season_name                Main
# crop_production_system All (PS)
# fnid_short               1990A1 2013A1 2016A1 2021A1
# year
# 2002                      11/11    NaN    NaN    NaN
# 2003                      11/11    NaN    NaN    NaN
# 2004                        NaN    NaN    NaN    NaN
# 2005                      11/11    NaN    NaN    NaN
# 2006                      11/11    NaN    NaN    NaN
# 2007                      10/11    NaN    NaN    NaN
# 2008                      10/11    NaN    NaN    NaN
# 2009                        NaN    NaN    NaN    NaN
# 2010                      11/11    NaN    NaN    NaN
# 2011                        NaN    NaN    NaN    NaN
# 2012                      10/11    NaN    NaN    NaN
# 2013                        NaN    NaN    NaN    NaN
# 2014                        NaN  10/11    NaN    NaN
# 2015                        NaN  10/11    NaN    NaN
# 2016                        NaN    NaN  10/11    NaN
# 2017                        NaN    NaN  10/11    NaN
# 2018                        NaN    NaN  10/11    NaN
# 2019                        NaN    NaN  10/11    NaN
# 2020                        NaN    NaN  10/11    NaN
# 2021                        NaN    NaN    NaN  10/11
# 2022                        NaN    NaN    NaN  10/11
# ----------------------------------------------- #
# Crop type: Cucumber
# ----------------------------------------------- #
# season_name                Main
# crop_production_system All (PS)
# fnid_short               1990A1 2013A1
# year
# 2000                       8/11    NaN
# 2001                        NaN    NaN
# 2002                        NaN    NaN
# 2003                        NaN    NaN
# 2004                        NaN    NaN
# 2005                        NaN    NaN
# 2006                        NaN    NaN
# 2007                        NaN    NaN
# 2008                        NaN    NaN
# 2009                        NaN    NaN
# 2010                      11/11    NaN
# 2011                        NaN    NaN
# 2012                        NaN    NaN
# 2013                        NaN    NaN
# 2014                        NaN    NaN
# 2015                        NaN  10/11
# ----------------------------------------------- #
# Crop type: Eggplant
# ----------------------------------------------- #
# season_name                Main
# crop_production_system All (PS)
# fnid_short               1990A1 2013A1
# year
# 2010                      11/11    NaN
# 2011                        NaN    NaN
# 2012                        NaN    NaN
# 2013                        NaN    NaN
# 2014                        NaN    NaN
# 2015                        NaN   6/11
# ----------------------------------------------- #
# Crop type: Garlic (fresh)
# ----------------------------------------------- #
# season_name                Main
# crop_production_system All (PS)
# fnid_short               1990A1 2013A1
# year
# 2000                       6/11    NaN
# 2001                        NaN    NaN
# 2002                        NaN    NaN
# 2003                        NaN    NaN
# 2004                        NaN    NaN
# 2005                        NaN    NaN
# 2006                        NaN    NaN
# 2007                        NaN    NaN
# 2008                        NaN    NaN
# 2009                        NaN    NaN
# 2010                      11/11    NaN
# 2011                        NaN    NaN
# 2012                        NaN    NaN
# 2013                        NaN    NaN
# 2014                        NaN    NaN
# 2015                        NaN   6/11
# ----------------------------------------------- #
# Crop type: Ginger
# ----------------------------------------------- #
# season_name                Main
# crop_production_system All (PS)
# fnid_short               1990A1 2013A1
# year
# 2000                       6/11    NaN
# 2001                        NaN    NaN
# 2002                       2/11    NaN
# 2003                        NaN    NaN
# 2004                        NaN    NaN
# 2005                       2/11    NaN
# 2006                        NaN    NaN
# 2007                        NaN    NaN
# 2008                       1/11    NaN
# 2009                        NaN    NaN
# 2010                       6/11    NaN
# 2011                        NaN    NaN
# 2012                        NaN    NaN
# 2013                        NaN    NaN
# 2014                        NaN   1/11
# 2015                        NaN   1/11
# ----------------------------------------------- #
# Crop type: Green bean (fresh)
# ----------------------------------------------- #
# season_name                Main
# crop_production_system All (PS)
# fnid_short               1990A1 2013A1 2016A1
# year
# 2002                      10/11    NaN    NaN
# 2003                      10/11    NaN    NaN
# 2004                        NaN    NaN    NaN
# 2005                      10/11    NaN    NaN
# 2006                      10/11    NaN    NaN
# 2007                      10/11    NaN    NaN
# 2008                      10/11    NaN    NaN
# 2009                        NaN    NaN    NaN
# 2010                      11/11    NaN    NaN
# 2011                        NaN    NaN    NaN
# 2012                        NaN    NaN    NaN
# 2013                        NaN    NaN    NaN
# 2014                        NaN    NaN    NaN
# 2015                        NaN   6/11    NaN
# 2016                        NaN    NaN    NaN
# 2017                        NaN    NaN    NaN
# 2018                        NaN    NaN    NaN
# 2019                        NaN    NaN    NaN
# 2020                        NaN    NaN   7/11
# ----------------------------------------------- #
# Crop type: Groundnuts (In Shell)
# ----------------------------------------------- #
# season_name                Main
# crop_production_system All (PS)
# fnid_short               1990A1 2016A1
# year
# 1999                       7/11    NaN
# 2000                      10/11    NaN
# 2001                      10/11    NaN
# 2002                      10/11    NaN
# 2003                      10/11    NaN
# 2004                      10/11    NaN
# 2005                      10/11    NaN
# 2006                      10/11    NaN
# 2007                      10/11    NaN
# 2008                      10/11    NaN
# 2009                      10/11    NaN
# 2010                      11/11    NaN
# 2011                      10/11    NaN
# 2012                        NaN    NaN
# 2013                        NaN    NaN
# 2014                        NaN    NaN
# 2015                        NaN    NaN
# 2016                        NaN    NaN
# 2017                        NaN    NaN
# 2018                        NaN  10/11
# ----------------------------------------------- #
# Crop type: Groundnuts (In Shell, Large)
# ----------------------------------------------- #
# season_name                Main
# crop_production_system All (PS)
# fnid_short               1990A1
# year
# 2002                      10/11
# 2003                      10/11
# 2004                        NaN
# 2005                      10/11
# 2006                      10/11
# ----------------------------------------------- #
# Crop type: Groundnuts (In Shell, Small)
# ----------------------------------------------- #
# season_name                Main
# crop_production_system All (PS)
# fnid_short               1990A1
# year
# 2002                      10/11
# 2003                        NaN
# 2004                        NaN
# 2005                      10/11
# 2006                      10/11
# ----------------------------------------------- #
# Crop type: Jute
# ----------------------------------------------- #
# season_name              Annual
# crop_production_system All (PS)
# fnid_short               1990A1 2013A1 2016A1
# year
# 2010                       2/11    NaN    NaN
# 2011                        NaN    NaN    NaN
# 2012                        NaN    NaN    NaN
# 2013                        NaN    NaN    NaN
# 2014                        NaN    NaN    NaN
# 2015                        NaN   1/11    NaN
# 2016                        NaN    NaN    NaN
# 2017                        NaN    NaN    NaN
# 2018                        NaN    NaN    NaN
# 2019                        NaN    NaN    NaN
# 2020                        NaN    NaN   1/11
# ----------------------------------------------- #
# Crop type: Kale
# ----------------------------------------------- #
# season_name                Main
# crop_production_system All (PS)
# fnid_short               1990A1 2013A1
# year
# 2000                       8/11    NaN
# 2001                        NaN    NaN
# 2002                        NaN    NaN
# 2003                        NaN    NaN
# 2004                        NaN    NaN
# 2005                        NaN    NaN
# 2006                        NaN    NaN
# 2007                        NaN    NaN
# 2008                        NaN    NaN
# 2009                        NaN    NaN
# 2010                      10/11    NaN
# 2011                        NaN    NaN
# 2012                        NaN    NaN
# 2013                        NaN    NaN
# 2014                        NaN    NaN
# 2015                        NaN   9/11
# ----------------------------------------------- #
# Crop type: Lettuce (Unspecified)
# ----------------------------------------------- #
# season_name                Main
# crop_production_system All (PS)
# fnid_short               1990A1 2013A1
# year
# 2000                       6/11    NaN
# 2001                        NaN    NaN
# 2002                        NaN    NaN
# 2003                        NaN    NaN
# 2004                        NaN    NaN
# 2005                        NaN    NaN
# 2006                        NaN    NaN
# 2007                        NaN    NaN
# 2008                        NaN    NaN
# 2009                        NaN    NaN
# 2010                      11/11    NaN
# 2011                        NaN    NaN
# 2012                        NaN    NaN
# 2013                        NaN    NaN
# 2014                        NaN    NaN
# 2015                        NaN  10/11
# ----------------------------------------------- #
# Crop type: Macadamia (unspecified)
# ----------------------------------------------- #
# season_name              Annual
# crop_production_system All (PS)
# fnid_short               2016A1
# year
# 2020                       4/11
# ----------------------------------------------- #
# Crop type: Maize Grain (White)
# ----------------------------------------------- #
# season_name                Main
# crop_production_system All (PS)
# fnid_short               1990A1 2013A1 2016A1 2021A1
# year
# 1999                       6/11    NaN    NaN    NaN
# 2000                      10/11    NaN    NaN    NaN
# 2001                      10/11    NaN    NaN    NaN
# 2002                      11/11    NaN    NaN    NaN
# 2003                      11/11    NaN    NaN    NaN
# 2004                      10/11    NaN    NaN    NaN
# 2005                      11/11    NaN    NaN    NaN
# 2006                      11/11    NaN    NaN    NaN
# 2007                      10/11    NaN    NaN    NaN
# 2008                      10/11    NaN    NaN    NaN
# 2009                      10/11    NaN    NaN    NaN
# 2010                       8/11    NaN    NaN    NaN
# 2011                      10/11    NaN    NaN    NaN
# 2012                      10/11    NaN    NaN    NaN
# 2013                        NaN    NaN    NaN    NaN
# 2014                        NaN  10/11    NaN    NaN
# 2015                        NaN   4/11    NaN    NaN
# 2016                        NaN    NaN  10/11    NaN
# 2017                        NaN    NaN   9/11    NaN
# 2018                        NaN    NaN  10/11    NaN
# 2019                        NaN    NaN  10/11    NaN
# 2020                        NaN    NaN  10/11    NaN
# 2021                        NaN    NaN    NaN  10/11
# 2022                        NaN    NaN    NaN  10/11
# ----------------------------------------------- #
# Crop type: Millet
# ----------------------------------------------- #
# season_name                Main
# crop_production_system All (PS)
# fnid_short               1990A1 2013A1 2016A1 2021A1
# year
# 2000                       9/11    NaN    NaN    NaN
# 2001                        NaN    NaN    NaN    NaN
# 2002                      11/11    NaN    NaN    NaN
# 2003                       9/11    NaN    NaN    NaN
# 2004                        NaN    NaN    NaN    NaN
# 2005                       9/11    NaN    NaN    NaN
# 2006                      11/11    NaN    NaN    NaN
# 2007                       9/11    NaN    NaN    NaN
# 2008                       9/11    NaN    NaN    NaN
# 2009                        NaN    NaN    NaN    NaN
# 2010                      10/11    NaN    NaN    NaN
# 2011                        NaN    NaN    NaN    NaN
# 2012                      10/11    NaN    NaN    NaN
# 2013                        NaN    NaN    NaN    NaN
# 2014                        NaN  10/11    NaN    NaN
# 2015                        NaN   6/11    NaN    NaN
# 2016                        NaN    NaN  10/11    NaN
# 2017                        NaN    NaN  10/11    NaN
# 2018                        NaN    NaN  10/11    NaN
# 2019                        NaN    NaN  10/11    NaN
# 2020                        NaN    NaN  10/11    NaN
# 2021                        NaN    NaN    NaN  10/11
# 2022                        NaN    NaN    NaN  10/11
# ----------------------------------------------- #
# Crop type: Mung bean (unspecified)
# ----------------------------------------------- #
# season_name                Main
# crop_production_system All (PS)
# fnid_short               2013A1 2016A1
# year
# 2015                       7/11    NaN
# 2016                        NaN    NaN
# 2017                        NaN    NaN
# 2018                        NaN    NaN
# 2019                        NaN    NaN
# 2020                        NaN   7/11
# ----------------------------------------------- #
# Crop type: Okras (Fresh)
# ----------------------------------------------- #
# season_name                Main
# crop_production_system All (PS)
# fnid_short               1990A1 2013A1
# year
# 2010                      11/11    NaN
# 2011                        NaN    NaN
# 2012                        NaN    NaN
# 2013                        NaN    NaN
# 2014                        NaN    NaN
# 2015                        NaN   9/11
# ----------------------------------------------- #
# Crop type: Onions
# ----------------------------------------------- #
# season_name                Main
# crop_production_system All (PS)
# fnid_short               1990A1 2013A1
# year
# 2000                       9/11    NaN
# 2001                        NaN    NaN
# 2002                        NaN    NaN
# 2003                        NaN    NaN
# 2004                        NaN    NaN
# 2005                        NaN    NaN
# 2006                        NaN    NaN
# 2007                        NaN    NaN
# 2008                        NaN    NaN
# 2009                        NaN    NaN
# 2010                      11/11    NaN
# 2011                        NaN    NaN
# 2012                        NaN    NaN
# 2013                        NaN    NaN
# 2014                        NaN    NaN
# 2015                        NaN  10/11
# ----------------------------------------------- #
# Crop type: Other root/tuber vegetable (unspecified)
# ----------------------------------------------- #
# season_name              Annual
# crop_production_system All (PS)
# fnid_short               2013A1 2016A1
# year
# 2015                      10/11    NaN
# 2016                        NaN  10/11
# 2017                        NaN  10/11
# 2018                        NaN  10/11
# 2019                        NaN  10/11
# ----------------------------------------------- #
# Crop type: Paprika (unspecified)
# ----------------------------------------------- #
# season_name                Main
# crop_production_system All (PS)
# fnid_short               1990A1
# year
# 2002                       2/11
# 2003                       1/11
# 2004                        NaN
# 2005                       4/11
# 2006                       2/11
# 2007                        NaN
# 2008                       1/11
# ----------------------------------------------- #
# Crop type: Pea (unspecified)
# ----------------------------------------------- #
# season_name                Main
# crop_production_system All (PS)
# fnid_short               1990A1 2013A1
# year
# 2000                       6/11    NaN
# 2001                        NaN    NaN
# 2002                        NaN    NaN
# 2003                        NaN    NaN
# 2004                        NaN    NaN
# 2005                        NaN    NaN
# 2006                        NaN    NaN
# 2007                        NaN    NaN
# 2008                        NaN    NaN
# 2009                        NaN    NaN
# 2010                       8/11    NaN
# 2011                        NaN    NaN
# 2012                        NaN    NaN
# 2013                        NaN    NaN
# 2014                        NaN    NaN
# 2015                        NaN   5/11
# ----------------------------------------------- #
# Crop type: Pepper (Piper spp.)
# ----------------------------------------------- #
# season_name                Main
# crop_production_system All (PS)
# fnid_short               1990A1 2013A1
# year
# 2000                       8/11    NaN
# 2001                        NaN    NaN
# 2002                       2/11    NaN
# 2003                       1/11    NaN
# 2004                        NaN    NaN
# 2005                       4/11    NaN
# 2006                       3/11    NaN
# 2007                       1/11    NaN
# 2008                       2/11    NaN
# 2009                        NaN    NaN
# 2010                      11/11    NaN
# 2011                        NaN    NaN
# 2012                        NaN    NaN
# 2013                        NaN    NaN
# 2014                        NaN    NaN
# 2015                        NaN   8/11
# ----------------------------------------------- #
# Crop type: Pigeon pea (Unspecified)
# ----------------------------------------------- #
# season_name                Main
# crop_production_system All (PS)
# fnid_short               1990A1 2013A1 2016A1 2021A1
# year
# 2002                      11/11    NaN    NaN    NaN
# 2003                      11/11    NaN    NaN    NaN
# 2004                        NaN    NaN    NaN    NaN
# 2005                      11/11    NaN    NaN    NaN
# 2006                      11/11    NaN    NaN    NaN
# 2007                      10/11    NaN    NaN    NaN
# 2008                      10/11    NaN    NaN    NaN
# 2009                        NaN    NaN    NaN    NaN
# 2010                      11/11    NaN    NaN    NaN
# 2011                        NaN    NaN    NaN    NaN
# 2012                      10/11    NaN    NaN    NaN
# 2013                        NaN    NaN    NaN    NaN
# 2014                        NaN  10/11    NaN    NaN
# 2015                        NaN  10/11    NaN    NaN
# 2016                        NaN    NaN  10/11    NaN
# 2017                        NaN    NaN  10/11    NaN
# 2018                        NaN    NaN  10/11    NaN
# 2019                        NaN    NaN  10/11    NaN
# 2020                        NaN    NaN  10/11    NaN
# 2021                        NaN    NaN    NaN  10/11
# 2022                        NaN    NaN    NaN  10/11
# ----------------------------------------------- #
# Crop type: Potato (Irish)
# ----------------------------------------------- #
# season_name                Main
# crop_production_system All (PS)
# fnid_short               1990A1 2013A1
# year
# 2012                       4/11    NaN
# 2013                        NaN    NaN
# 2014                        NaN   6/11
# ----------------------------------------------- #
# Crop type: Potato (unspecified)
# ----------------------------------------------- #
# season_name                Main
# crop_production_system All (PS)
# fnid_short               1990A1 2013A1 2016A1
# year
# 2010                      10/11    NaN    NaN
# 2011                        NaN    NaN    NaN
# 2012                       4/11    NaN    NaN
# 2013                        NaN    NaN    NaN
# 2014                        NaN   6/11    NaN
# 2015                        NaN   7/11    NaN
# 2016                        NaN    NaN    NaN
# 2017                        NaN    NaN    NaN
# 2018                        NaN    NaN    NaN
# 2019                        NaN    NaN    NaN
# 2020                        NaN    NaN  10/11
# ----------------------------------------------- #
# Crop type: Rice (Paddy)
# ----------------------------------------------- #
# season_name            Rice season
# crop_production_system    All (PS)
# fnid_short                  1990A1 2013A1 2016A1 2021A1
# year
# 1999                          9/11    NaN    NaN    NaN
# 2000                         10/11    NaN    NaN    NaN
# 2001                           NaN    NaN    NaN    NaN
# 2002                         11/11    NaN    NaN    NaN
# 2003                         11/11    NaN    NaN    NaN
# 2004                           NaN    NaN    NaN    NaN
# 2005                         11/11    NaN    NaN    NaN
# 2006                         11/11    NaN    NaN    NaN
# 2007                         10/11    NaN    NaN    NaN
# 2008                         10/11    NaN    NaN    NaN
# 2009                           NaN    NaN    NaN    NaN
# ...
# 2018                        NaN    NaN   4/11    NaN                    NaN    NaN         NaN
# 2019                        NaN    NaN   4/11    NaN                    NaN    NaN         NaN
# 2020                        NaN    NaN   5/11    NaN                    NaN    NaN         NaN
# 2021                        NaN    NaN    NaN   5/11                    NaN    NaN         NaN
# 2022                        NaN    NaN    NaN   5/11                    NaN    NaN         NaN
# ----------------------------------------------- #
# Crop type: Sweet Potatoes
# ----------------------------------------------- #
# season_name                Main
# crop_production_system All (PS)
# fnid_short               1990A1 2013A1 2016A1
# year
# 2000                      10/11    NaN    NaN
# 2001                        NaN    NaN    NaN
# 2002                      10/11    NaN    NaN
# 2003                        NaN    NaN    NaN
# 2004                        NaN    NaN    NaN
# 2005                        NaN    NaN    NaN
# 2006                      10/11    NaN    NaN
# 2007                      10/11    NaN    NaN
# 2008                      10/11    NaN    NaN
# 2009                        NaN    NaN    NaN
# 2010                      11/11    NaN    NaN
# 2011                        NaN    NaN    NaN
# 2012                        NaN    NaN    NaN
# 2013                        NaN    NaN    NaN
# 2014                        NaN  10/11    NaN
# 2015                        NaN    NaN    NaN
# 2016                        NaN    NaN    NaN
# 2017                        NaN    NaN    NaN
# 2018                        NaN    NaN  10/11
# ----------------------------------------------- #
# Crop type: Sweet Potatoes (Non-Orange)
# ----------------------------------------------- #
# season_name                Main
# crop_production_system All (PS)                      Small_and_medium_scale
# fnid_short               1990A1 2013A1 2016A1 2021A1                 1990A1 2013A1 2016A1
# year
# 2005                      10/11    NaN    NaN    NaN                    NaN    NaN    NaN
# 2006                      10/11    NaN    NaN    NaN                    NaN    NaN    NaN
# 2007                      10/11    NaN    NaN    NaN                    NaN    NaN    NaN
# 2008                      10/11    NaN    NaN    NaN                    NaN    NaN    NaN
# 2009                        NaN    NaN    NaN    NaN                    NaN    NaN    NaN
# 2010                        NaN    NaN    NaN    NaN                    NaN    NaN    NaN
# 2011                        NaN    NaN    NaN    NaN                    NaN    NaN    NaN
# 2012                      10/11    NaN    NaN    NaN                  10/11    NaN    NaN
# 2013                        NaN    NaN    NaN    NaN                    NaN   1/11    NaN
# 2014                        NaN  10/11    NaN    NaN                    NaN  10/11    NaN
# 2015                        NaN  10/11    NaN    NaN                    NaN   3/11    NaN
# 2016                        NaN    NaN  10/11    NaN                    NaN    NaN    NaN
# 2017                        NaN    NaN  10/11    NaN                    NaN    NaN    NaN
# 2018                        NaN    NaN  10/11    NaN                    NaN    NaN    NaN
# 2019                        NaN    NaN  10/11    NaN                    NaN    NaN    NaN
# 2020                        NaN    NaN  10/11    NaN                    NaN    NaN   9/11
# 2021                        NaN    NaN    NaN  10/11                    NaN    NaN    NaN
# 2022                        NaN    NaN    NaN  10/11                    NaN    NaN    NaN
# ----------------------------------------------- #
# Crop type: Sweet Potatoes (Orange)
# ----------------------------------------------- #
# season_name                Main
# crop_production_system All (PS)                      Small_and_medium_scale
# fnid_short               1990A1 2013A1 2016A1 2021A1                 1990A1 2013A1 2016A1
# year
# 2002                      10/11    NaN    NaN    NaN                    NaN    NaN    NaN
# 2003                        NaN    NaN    NaN    NaN                    NaN    NaN    NaN
# 2004                        NaN    NaN    NaN    NaN                    NaN    NaN    NaN
# 2005                      10/11    NaN    NaN    NaN                    NaN    NaN    NaN
# 2006                      10/11    NaN    NaN    NaN                    NaN    NaN    NaN
# 2007                      10/11    NaN    NaN    NaN                    NaN    NaN    NaN
# 2008                      10/11    NaN    NaN    NaN                    NaN    NaN    NaN
# 2009                        NaN    NaN    NaN    NaN                    NaN    NaN    NaN
# 2010                        NaN    NaN    NaN    NaN                    NaN    NaN    NaN
# 2011                        NaN    NaN    NaN    NaN                    NaN    NaN    NaN
# 2012                      10/11    NaN    NaN    NaN                  10/11    NaN    NaN
# 2013                        NaN    NaN    NaN    NaN                    NaN    NaN    NaN
# 2014                        NaN  10/11    NaN    NaN                    NaN  10/11    NaN
# 2015                        NaN  10/11    NaN    NaN                    NaN   3/11    NaN
# 2016                        NaN    NaN  10/11    NaN                    NaN    NaN    NaN
# 2017                        NaN    NaN  10/11    NaN                    NaN    NaN    NaN
# 2018                        NaN    NaN  10/11    NaN                    NaN    NaN    NaN
# 2019                        NaN    NaN  10/11    NaN                    NaN    NaN    NaN
# 2020                        NaN    NaN  10/11    NaN                    NaN    NaN  10/11
# 2021                        NaN    NaN    NaN  10/11                    NaN    NaN    NaN
# 2022                        NaN    NaN    NaN  10/11                    NaN    NaN    NaN
# ----------------------------------------------- #
# Crop type: Tea leaves (Mixed)
# ----------------------------------------------- #
# season_name              Annual                        Main
# crop_production_system All (PS)        large_scale All (PS)
# fnid_short               2013A1 2016A1      2016A1   1990A1
# year
# 2000                        NaN    NaN         NaN     1/11
# 2001                        NaN    NaN         NaN      NaN
# 2002                        NaN    NaN         NaN      NaN
# 2003                        NaN    NaN         NaN      NaN
# 2004                        NaN    NaN         NaN      NaN
# 2005                        NaN    NaN         NaN      NaN
# 2006                        NaN    NaN         NaN      NaN
# 2007                        NaN    NaN         NaN      NaN
# 2008                        NaN    NaN         NaN      NaN
# 2009                        NaN    NaN         NaN      NaN
# 2010                        NaN    NaN         NaN     1/11
# 2011                        NaN    NaN         NaN      NaN
# 2012                        NaN    NaN         NaN      NaN
# 2013                        NaN    NaN         NaN      NaN
# 2014                        NaN    NaN         NaN      NaN
# 2015                       1/11    NaN         NaN      NaN
# 2016                        NaN    NaN         NaN      NaN
# 2017                        NaN    NaN         NaN      NaN
# 2018                        NaN    NaN         NaN      NaN
# 2019                        NaN    NaN         NaN      NaN
# 2020                        NaN   1/11        1/11      NaN
# ----------------------------------------------- #
# Crop type: Tobacco (unspecified)
# ----------------------------------------------- #
# season_name                Main
# crop_production_system All (PS)                      Small_and_medium_scale large_scale
# fnid_short               1990A1 2013A1 2016A1 2021A1                 2013A1      2013A1
# year
# 2000                       9/11    NaN    NaN    NaN                    NaN         NaN
# 2001                        NaN    NaN    NaN    NaN                    NaN         NaN
# 2002                      10/11    NaN    NaN    NaN                    NaN         NaN
# 2003                       9/11    NaN    NaN    NaN                    NaN         NaN
# 2004                        NaN    NaN    NaN    NaN                    NaN         NaN
# 2005                      10/11    NaN    NaN    NaN                    NaN         NaN
# 2006                      10/11    NaN    NaN    NaN                    NaN         NaN
# 2007                       9/11    NaN    NaN    NaN                    NaN         NaN
# 2008                       7/11    NaN    NaN    NaN                    NaN         NaN
# 2009                        NaN    NaN    NaN    NaN                    NaN         NaN
# 2010                      10/11    NaN    NaN    NaN                    NaN         NaN
# 2011                        NaN    NaN    NaN    NaN                    NaN         NaN
# 2012                        NaN    NaN    NaN    NaN                    NaN         NaN
# 2013                        NaN    NaN    NaN    NaN                    NaN         NaN
# 2014                        NaN    NaN    NaN    NaN                    NaN         NaN
# 2015                        NaN   9/11    NaN    NaN                   6/11        1/11
# 2016                        NaN    NaN  10/11    NaN                    NaN         NaN
# 2017                        NaN    NaN  10/11    NaN                    NaN         NaN
# 2018                        NaN    NaN  10/11    NaN                    NaN         NaN
# 2019                        NaN    NaN  10/11    NaN                    NaN         NaN
# 2020                        NaN    NaN   5/11    NaN                    NaN         NaN
# 2021                        NaN    NaN    NaN   5/11                    NaN         NaN
# 2022                        NaN    NaN    NaN   5/11                    NaN         NaN
# ----------------------------------------------- #
# Crop type: Tomato
# ----------------------------------------------- #
# season_name                Main
# crop_production_system All (PS)        Small_and_medium_scale
# fnid_short               1990A1 2013A1                 2013A1
# year
# 2010                      11/11    NaN                    NaN
# 2011                        NaN    NaN                    NaN
# 2012                        NaN    NaN                    NaN
# 2013                        NaN    NaN                    NaN
# 2014                        NaN    NaN                    NaN
# 2015                        NaN  10/11                  10/11
# ----------------------------------------------- #
# Crop type: Virginia peanut (in shell)
# ----------------------------------------------- #
# season_name                Main
# crop_production_system All (PS)                      Small_and_medium_scale               large_scale
# fnid_short               1990A1 2013A1 2016A1 2021A1                 1990A1 2013A1 2016A1      2013A1
# year
# 2002                      10/11    NaN    NaN    NaN                    NaN    NaN    NaN         NaN
# 2003                      10/11    NaN    NaN    NaN                    NaN    NaN    NaN         NaN
# 2004                        NaN    NaN    NaN    NaN                    NaN    NaN    NaN         NaN
# 2005                      10/11    NaN    NaN    NaN                    NaN    NaN    NaN         NaN
# 2006                      10/11    NaN    NaN    NaN                    NaN    NaN    NaN         NaN
# 2007                      10/11    NaN    NaN    NaN                    NaN    NaN    NaN         NaN
# 2008                      10/11    NaN    NaN    NaN                    NaN    NaN    NaN         NaN
# 2009                        NaN    NaN    NaN    NaN                    NaN    NaN    NaN         NaN
# 2010                        NaN    NaN    NaN    NaN                    NaN    NaN    NaN         NaN
# 2011                        NaN    NaN    NaN    NaN                    NaN    NaN    NaN         NaN
# 2012                      10/11    NaN    NaN    NaN                  10/11    NaN    NaN         NaN
# 2013                        NaN   4/11    NaN    NaN                    NaN    NaN    NaN         NaN
# 2014                        NaN  10/11    NaN    NaN                    NaN  10/11    NaN         NaN
# 2015                        NaN   5/11    NaN    NaN                    NaN   9/11    NaN        5/11
# 2016                        NaN    NaN  10/11    NaN                    NaN    NaN    NaN         NaN
# 2017                        NaN    NaN  10/11    NaN                    NaN    NaN    NaN         NaN
# 2018                        NaN    NaN  10/11    NaN                    NaN    NaN    NaN         NaN
# 2019                        NaN    NaN  10/11    NaN                    NaN    NaN    NaN         NaN
# 2020                        NaN    NaN  10/11    NaN                    NaN    NaN  10/11         NaN
# 2021                        NaN    NaN    NaN  10/11                    NaN    NaN    NaN         NaN
# 2022                        NaN    NaN    NaN  10/11                    NaN    NaN    NaN         NaN
# ----------------------------------------------- #
# Crop type: Watermelon
# ----------------------------------------------- #
# season_name                Main
# crop_production_system All (PS)        Small_and_medium_scale
# fnid_short               1990A1 2013A1                 2013A1
# year
# 2010                      11/11    NaN                    NaN
# 2011                        NaN    NaN                    NaN
# 2012                        NaN    NaN                    NaN
# 2013                        NaN    NaN                    NaN
# 2014                        NaN    NaN                    NaN
# 2015                        NaN  10/11                  10/11
# ----------------------------------------------- #
# Crop type: Wheat Grain
# ----------------------------------------------- #
# season_name                Main        Winter harvest
# crop_production_system All (PS)              All (PS) Small_and_medium_scale
# fnid_short               1990A1 2016A1         2013A1                 2013A1
# year
# 2010                       3/11    NaN            NaN                    NaN
# 2011                        NaN    NaN            NaN                    NaN
# 2012                        NaN    NaN            NaN                    NaN
# 2013                        NaN    NaN            NaN                    NaN
# 2014                        NaN    NaN            NaN                    NaN
# 2015                        NaN    NaN           1/11                   1/11
# 2016                        NaN    NaN            NaN                    NaN
# 2017                        NaN    NaN            NaN                    NaN
# 2018                        NaN   2/11            NaN                    NaN
# ----------------------------------------------- #
# Crop type: Yams
# ----------------------------------------------- #
# season_name                Main
# crop_production_system All (PS)
# fnid_short               1990A1
# year
# 2000                       9/11
# ----------------------------------------------- #
# ../figures/MZ_admin_shapes.png is saved.

# %% [markdown]
# - Mozambique crop seasonal calendar
#
# <img src="https://fews.net/sites/default/files/styles/large_width_880/public/2023-03/seasonal-calendar-mozambique.png?itok=hpXyM51B" width=900><br>
#
# <img src="https://ipad.fas.usda.gov/countrysummary/images/MZ/cropcalendar/safrica_mz_calendar.png" width=900>
#
# - comparison of boundaries
#
# <img src="../figures/MZ_admin_shapes.png" width=900>
#
# - In Mozambique, basd on the FEWS NET data, there were three changes in administrative units: 2013, 2016, and 2021
# - While the admin unit 1 doesn't change between 1990 and 2013, we will still need to map between FNIDs
#
# | year	 | Admin1   | # units   | Admin2   | # units   |
# | :---: | :----:  | :----:   | :----:   | :---:  |
# | 1990	 | MZ1990A1 | 11	| MZ1990A2	| 142	|
# | 2013	 | MZ2013A1 | 11	| MZ2013A2	| 154	|
# | 2016	 | MZ2016A1 | 11	| MZ2016A2	| 157	|
# | 2021	 | MZ2021A1 | 11	| MZ2021A2	| 158	|
#
# - **`MZ2021A1`** is used to represent current admin-level 1 crop data.
# - The data is all reported in a single `Main` season

# %%
# Define the latest shapefile ------------------- #
latest_level = 1
shape_latest = MZ_Admin1_2021.copy().to_crs('epsg:4326')
# ----------------------------------------------- #

# Validation of FNIDs and Names ----------------- #
df = FDW_PD_ValidateFnidName(df, shape_used, shape_latest)
# ----------------------------------------------- #

# FDW Production Data Compiling ----------------- #
area, prod = FDW_PD_Compiling(df, shape_used)
area_all, prod_all = area.copy(), prod.copy()
mdx_pss = area.columns.droplevel([0,1]).unique()
# ----------------------------------------------- #

# %%
# Link admin boundaries ------------------------- #
link_1990, over_1990 = FDW_PD_CreateAdminLink(MZ_Admin1_1990, MZ_Admin1_2021, 'ADMIN1', 'ADMIN1', prod, epsg)
link_1990['MZ1990A106'].update(method='PBR')
link_2013, over_2013 = FDW_PD_CreateAdminLink(MZ_Admin1_2013, MZ_Admin1_2021, 'ADMIN1', 'ADMIN1', prod, epsg)
link_2013['MZ2013A106'].update(method='PBR')
link_2016, over_2016 = FDW_PD_CreateAdminLink(MZ_Admin1_2016, MZ_Admin1_2021, 'ADMIN1', 'ADMIN1', prod, epsg)
link_2016['MZ2016A106'].update(method='PBR')
# Crop specific ratios
link_ratio_1990 = FDW_PD_RatioAdminLink(link_1990, prod, over_1990, mdx_pss)
link_ratio_2013 = FDW_PD_RatioAdminLink(link_2013, prod, over_2013, mdx_pss)
link_ratio_2016 = FDW_PD_RatioAdminLink(link_2016, prod, over_2016, mdx_pss)
link_merged = [link_ratio_1990, link_ratio_2013, link_ratio_2016]
fnids_new = list(link_merged[0].keys())
link_ratio = dict()
for fnid in fnids_new:
    container = []
    for link in link_merged:
        container.append(link[fnid])
    link_ratio[fnid] = pd.concat(container, axis=1)
# Add current unit to link_ratio
for fnid_new in link_ratio.keys():
    link_ratio[fnid_new][fnid_new] = 1.0
    link_ratio[fnid_new] = link_ratio[fnid_new].sort_index(axis=1, ascending=False)
# Connect data with AdminLink
area_new, prod_new = FDW_PD_ConnectAdminLink(link_ratio, area, prod, validation=False)
# ----------------------------------------------- #
# Out:
# CBR is considered for 'MZ1990A106' as no record found in: ['MZ2021A106']
# CBR is considered for 'MZ2013A106' as no record found in: ['MZ2021A106']
# CBR is considered for 'MZ2016A106' as no record found in: ['MZ2021A106']
# CBR is considered for 'MZ2013A106' as no record found in: ['MZ2021A106']
# CBR is considered for 'MZ2016A106' as no record found in: ['MZ2021A106']

# %%
# Manual correction ----------------------------- #
# Potential typo: 4.0 -> 40. Using an area of 4 results in sorghum yield >8 t/ha. Only change if it's not fixed in the underlying data
if (area_new.loc[2015,pd.IndexSlice['MZ2021A105',:,'Sorghum','Main','04-01','04-01','All (PS)']].values[0] == 4):
    area_new.loc[2015,pd.IndexSlice['MZ2021A105',:,'Sorghum','Main','04-01','04-01','All (PS)']] = 40
crop_new = prod_new/area_new
# ----------------------------------------------- #

# Complete long format DataFrame ---------------- #
df_area = area_new.T.stack().rename('value').reset_index()
df_area['indicator'] = 'area'
df_prod = prod_new.T.stack().rename('value').reset_index()
df_prod['indicator'] = 'production'
df_yield = crop_new.T.stack().rename('value').reset_index()
df_yield['indicator'] = 'yield'
stack = pd.concat([df_area, df_prod, df_yield], axis=0)
# Add "planting year"
cols = ['season_name','product','crop_production_system','planting_month','harvest_year','harvest_month','planting_year']
season_table = df[cols].drop_duplicates()
stack = stack.merge(season_table, on=cols[:-1])
# Add country and admin names
stack = stack.merge(df[['fnid','country','country_code','admin_1','admin_2']].drop_duplicates(), on='fnid', how='inner')
names = [
    'fnid','country','country_code','admin_1','admin_2','name',
    'product','season_name','planting_year','planting_month','harvest_year','harvest_month',
    'crop_production_system','indicator','value'
]
stack = stack[names]
# ----------------------------------------------- #

# Final Processing ------------------------------ #
# Product name mapping
stack = product_name_mapping(stack, list_except=None)
# Calibration of crop calendar using External Season Calendar (ESC)
esc = pd.read_csv('../data/crop_calendar/external_season_calendar.csv')
stack, link_ratio = FDW_PD_CaliSeasonYear(stack, esc, link_ratio=None)
# None admin names
stack.loc[stack['admin_1'].isna(), 'admin_1'] = 'none'
stack.loc[stack['admin_2'].isna(), 'admin_2'] = 'none'
# ----------------------------------------------- #
# Out:
# All [country, season_name] are in the external season calendar.

# %%
# Save data
fn_out = '../data/crop/adm_crop_production_MZ.csv'
stack.to_csv(fn_out); print(f'{fn_out} is saved.')
# Out:
# ../data/crop/adm_crop_production_MZ.csv is saved.

# %% [markdown]
# # Visualization of production data

# %%
# Bar chart of national crop production
country_iso, country_name = 'MZ', 'Mozambique'
df = pd.read_csv('../data/crop/adm_crop_production_%s.csv' % country_iso, index_col=0)
df['year'] = df['harvest_year']
year = [df['year'].min(), df['year'].max()]
for season_name in ['Main']:
    footnote = 'National crop production of %s - %s' % (country_name, season_name)
    fn_save = '../figures/%s_bar_natgrainprod_%s.png' % (country_iso, season_name)
    sub = df[df['season_name'] == season_name]
    PlotBarProduction(sub, year, footnote, fn_save)
# Out:
# /Users/weston/Documents/Code/Project/HarvestStat/HarvestStat/notebook/tools_graphic.py:135: UserWarning: First parameter to grid() is false, but line properties are supplied. The grid will be enabled.
#   axes[1].grid(which='minor', axis='x', linestyle='-', color='black', visible=False)
# ../figures/MZ_bar_natgrainprod_Main.png is saved.

# %%
# Lineplot of Production-Area-Yield time-series
country_iso, country_name ='MZ', 'Mozambique'
df = pd.read_csv('../data/crop/adm_crop_production_%s.csv' % country_iso, index_col=0)
df['year'] = df['harvest_year']
year = [df['year'].min(), df['year'].max()]
product_season = [
    ['Cassava','Annual'],
    ['Maize','Main'],
    ['Sorghum','Main'],
    ['Sweet Potatoes','Main'],
]
for product_name, season_name in product_season:
    footnote = 'Time-series of %s - %s - %s' % (country_iso, product_name, season_name)
    fn_save = '../figures/%s_line_pay_%s_%s.png' % (country_iso, product_name, season_name)
    sub = df[(df['product'] == product_name) & (df['season_name'] == season_name)]
    PlotLinePAY(sub, year, footnote)
